# %%
import pandas as pd

# %%
titanic = pd.read_csv('./titanic.csv')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ## 1. 타이타닉 호에 탑승한 이름 열만 출력하세요

# %%
titanic[["name"]]
# Out:
#                                                  name
# 0                       Allen, Miss. Elisabeth Walton
# 1                      Allison, Master. Hudson Trevor
# 2                        Allison, Miss. Helen Loraine
# 3                Allison, Mr. Hudson Joshua Creighton
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...                                               ...
# 1304                             Zabour, Miss. Hileni
# 1305                            Zabour, Miss. Thamine
# 1306                        Zakarian, Mr. Mapriededer
# 1307                              Zakarian, Mr. Ortin
# 1308                               Zimmerman, Mr. Leo
#
# [1309 rows x 1 columns]

# %% [markdown]
# ## 2. 타이타닉 호에서 생존한 사람만 조회하세요

# %%
titanic[titanic["survived"] == 1]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %% [markdown]
# ## 3. 타이타닉 호에 탑승한 사람 중 40세 이상의 사람들을 조회하세요

# %%
titanic[titanic["age"] >= 40]
# Out:
#       pclass  survived                                           name     sex  \
# 5          1         1                            Anderson, Mr. Harry    male
# 6          1         1              Andrews, Miss. Kornelia Theodosia  female
# 8          1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9          1         0                        Artagaveytia, Mr. Ramon    male
# 10         1         0                         Astor, Col. John Jacob    male
# ...      ...       ...                                            ...     ...
# 1264       3         0                van Billiard, Mr. Austin Blyler    male
# 1272       3         0                    Vander Cruyssen, Mr. Victor    male
# 1287       3         0               Widegren, Mr. Carl/Charles Peter    male
# 1290       3         1               Wilkes, Mrs. James (Ellen Needs)  female
# 1301       3         0                           Youseff, Mr. Gerious    male
#
# ...

# %% [markdown]
# ## 4. 타이타닉 호에 탑승한 사람 중 40세 이상이면서 생존한 사람을 조회하세요

# %%
titanic[(titanic["age"] >= 40) & (titanic["survived"] == 1)]
# Out:
#       pclass  survived                                             name  \
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 14         1         1             Barkworth, Mr. Algernon Henry Wilson
# 17         1         1  Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# ...      ...       ...                                              ...
# 742        3         1                            Dahl, Mr. Karl Edwart
# 851        3         1       Hansen, Mrs. Claus Peter (Jennie L Howard)
# 1233       3         1                        Sundman, Mr. Johan Julian
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
#
#          sex   age  sibsp  parch             ticket      fare    cabin  \
# ...

# %% [markdown]
# ## 5. 타이타닉 호 데이터 중 home.dest, body, boat 열을 삭제하세요. (원본 데이터가 손상되지 않도록 하세요)

# %%
df2 = titanic.drop(columns=["home.dest", "body","boat"]).copy()
df2
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked
# ...

# %% [markdown]
# ## 6. 타이타닉 호에 탑승한 사람들이 낸 티켓값의 합계를 출력하세요

# %%
titanic["fare"].sum()
# Out:
# 43550.4869

# %% [markdown]
# ## 7. 타이타닉 호 데이터의 열 마다의 결측치의 개수를 출력하세요

# %%
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           275
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %% [markdown]
# ## 8. 타이타닉 호 데이터의 총 결측치의 개수를 출력하세요.

# %%
s = 0
for i in list(titanic.isnull().sum()):
    if i != 0:
        s += int(i)

s
# Out:
# 3867

# %% [markdown]
# ## 9. 타이타닉 호 데이터의 home.dest 열 중  결측치가 아닌 데이터의 개수를 출력하세요

# %%
c = 0
for i in (list(titanic["home.dest"])):
    if type(i) == type(str()):
        c += 1

c
# Out:
# 745

# %% [markdown]
# ## 10. 타이타닉 호 데이터의 티켓 번호를 오름차순으로 정렬하세요 (숫자 ~문자)

# %%
df = titanic.sort_values("ticket")
df["ticket"]
# Out:
# 67          110152
# 245         110152
# 195         110152
# 289         110413
# 291         110413
#           ...
# 63     W.E.P. 5734
# 62     W.E.P. 5734
# 433      W/C 14208
# 81       WE/P 5735
# 82       WE/P 5735
# Name: ticket, Length: 1309, dtype: object

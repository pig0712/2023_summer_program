# %% [markdown]
# # Approximation(근사치)

# %% [markdown]
# ## 1. 근사화란 무엇인가?
#
# - 근사치는 참값(True value)과 비슷한 True value에 가까운 값을 의미함<br>
#
#
# - 참값(True value)을 계산하기 너무 어렵거나 알수 없는 경우 approximation을 이용함<br>
# $ \ \ $ $\checkmark \ $ 근사치를 사용하는 대표적인 경우는 숫자를 반올림하는 경우임
#
# Approximation 대상 | 대표적인 방법 |
# :----                       | :----
# <br> 미분가능함수                | <br> $\bullet \ $ Taylor Series  <br> $\bullet \ $ Fourier series
# <br> Data를 이용한 선형근사화    | <br> $\bullet \ $ Linear Regression
# <br> Data를 이용한 일반적 근사화 | <br> $\bullet \ $ Deep Neural Network

# %% [markdown]
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ## 2. Series를 이용한 근사화
#
# ### 2.1 Taylor Series
# - 미적분학(Differential and Integral Calculus)에서, 테일러 급수(Taylor Series)는 도함수(Derivative Function )들의 한 점에서의 값으로 계산된 항의 무한합으로 해석함수를 나타내는 방법<br>
#
#
# - 복잡한 함수 $f(x)$를 우리가 잘 다룰 수 있는 $x^{1}, x^{2}, ..., $으로 변환하는 방법

# %% [markdown]
# ##### (1) Taylor Series
#
# #### $ \ \ $ [Taylor Series 정의]
# > Smooth Function $f: R \rightarrow R$ 및 실수(real number) $a \in R$이 주어졌을 때, $f$의 Taylor Series는 다음과 같은 Power Series이다 <br><br>
# $$
# \begin{align}
# f(x) &=\sum_{n=0}^{\infty} \frac{f^{(n)}(a)}{n!}(x-a)^{n} \\
#        &= f(a) + f^{(1)}(a)(x-a) + \frac{1}{2} f^{(2)}(a)(x-a)^2 + \frac{1}{6} f^{(3)}(a)(x-a)^3 + \cdots
# \end{align}
# $$

# %% [markdown]
# #### $ \ \ $ [Maclaurin Series]
# - $a=0$인 Taylor Series<br><br>
# $$
# \begin{align}
# T_f(x) &=\sum_{n=0}^{\infty} \frac{f^{(n)}(0)}{n!}x^{n} \\
#        &= f(0) + f^{(1)}(0)x + \frac{1}{2} f^{(2)}(0)x^2 + \frac{1}{6} f^{(3)}(0)x^3 + \cdots
# \end{align}
# $$

# %% [markdown]
# #### $ \ \ $ [다변수 Taylor Series]
#
# - Taylor Series는 2개 이상의 다변수로 일반화될 수 있음. $d$개의 변수를 가지는 smooth function $f: R^{d} \rightarrow R$의 Taylor는 다음과 같다.<br><br>
# $$
# \begin{align}
# f(x_1, ..., x_d) &= \sum_{n_1=0}^{\infty} \cdots \sum_{n_d=0}^{\infty}
#      \frac{f^{(n_1)}(a_1) \cdots f^{(n_d)}(a_d)}{n_1! \cdots n_d!} (x_1-a_1)^{n_1} \cdots (x_d-a_d)^{n_d}\\
#        &= f(a_1 \cdots a_d)  \\
#        & \ \ \ + \frac{1}{1!} \sum_{j=1}^{d} \frac{\partial f(a_1, \cdots, a_d)}{\partial x_j} (x_j - a_j) \\
#        & \ \ \ + \frac{1}{2!} \sum_{k=1}^{d} \sum_{j=1}^{d}
#                     \frac{\partial^2 f(a_1, \cdots, a_d)}{\partial x_j \partial x_k}
#                     (x_k - a_k)(x_j - a_j) \\
#        & \ \ \ + \frac{1}{3!} \sum_{l=1}^{d} \sum_{k=1}^{d} \sum_{j=1}^{d}
#                     \frac{\partial^3 f(a_1, \cdots, a_d)}{\partial x_l \partial x_j \partial x_k}
#                     (x_l - a_l)(x_k - a_k)(x_j - a_j) + \cdots
# \end{align}
# $$

# %% [markdown]
# #### 연습문제
#
# - 다음과 같은 함수의 원점 $(0, 0)$에서 Taylor Series를 계산<br><br>
# $$
# f(x, y) = e^x log(1+y)
# $$

# %% [markdown]
# #### (2) Taylor Series를 이용한 선형 근사(Linear Approximation)
# - 선형 근사(Linear Approximation)는 어떤 함수를 선형 함수, 즉 일차 함수 만으로 근사하는 것을 말함<br>
# $ \ \ $ $\checkmark \ $ 어떤 점  $x=a$에서 미분가능한 함수 $f(x)$가 있을 때, $x=a$ 점에서 근사화한 함수는 다음과 같음
# <br>
# <br>
# $$
# f(x) = f(a) + f'(a)(x-a) + \varepsilon
# $$
# <br>
# $ \ \ $ $\checkmark \ $ 이 때 $f(x)$의 1차근사 approximation function은 다음과 같음
# <br>
# <br>
# $$
# f(x) \approx f(a) +f'(a)(x-a)$$
# <br>
# $ \ \ $ $\checkmark \ $ 위의 근사식을 $f$의 $a$에서의 선형근사(Linear Approximation)라고 한다
#
#
# - 이것은 Tayler 정리에 의하여 얻어진 $
# f(x) = f(a) + f'(a)(x-a) + \varepsilon
# $에서 approximation $\varepsilon \approx 0$를 취한 것으로 볼 수 있다.

# %% [markdown]
# #### 연습문제 1
# $\sqrt{4.01}$을 함수 $f(x)=\sqrt{x}$의 $a=4$에서의 Linear approximation을 사용해서 근사값을 구하시오

# %%
import numpy as np

def f_sqrt(x):
    return np.sqrt(x)

def d1_sqrt(x):
    return 1/(2*np.sqrt(x))

def approx(x, a):
    return f_sqrt(a) + d1_sqrt(a)*(x-a)

approx(4.01, 4)
# Out:
# 2.0025

# %%
np.sqrt(4.01)
# Out:
# 2.0024984394500787

# %%
approx(4.01, 4) - np.sqrt(4.01)
# Out:
# 1.5605499212867358e-06

# %%
a_set = np.linspace(2, 6, 30)
print(a_set)
# Out:
# [2.         2.13793103 2.27586207 2.4137931  2.55172414 2.68965517
#  2.82758621 2.96551724 3.10344828 3.24137931 3.37931034 3.51724138
#  3.65517241 3.79310345 3.93103448 4.06896552 4.20689655 4.34482759
#  4.48275862 4.62068966 4.75862069 4.89655172 5.03448276 5.17241379
#  5.31034483 5.44827586 5.5862069  5.72413793 5.86206897 6.        ]

# %%
app = approx(4.01, a_set)
error = np.abs(np.sqrt(4.01) - app)
error
# Out:
# array([1.22357438e-01, 9.98376500e-02, 8.08498604e-02, 6.48397536e-02,
#        5.13628600e-02, 4.00584074e-02, 3.06303588e-02, 2.28334188e-02,
#        1.64625453e-02, 1.13449771e-02, 7.33409609e-03, 4.30464734e-03,
#        2.14897689e-03, 7.74041965e-04, 9.90136808e-05, 5.33389250e-05,
#        5.75161556e-04, 1.61002712e-03, 3.10981314e-03, 5.03184033e-03,
#        7.33812971e-03, 9.99477847e-03, 1.29714328e-02, 1.62408408e-02,
#        1.97784708e-02, 2.35621854e-02, 2.75719606e-02, 3.17896441e-02,
#        3.61987455e-02, 4.07842543e-02])

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(5, 3))
plt.plot(a_set, error)
plt.title('Linear Approximation Error')
plt.xlabel('a: Approximation Point')
plt.ylabel('Error');
plt.show()

# %% [markdown]
# #### 연습문제 2
#
# - 함수 $f(x)=(x-4)^2-2$에 대해  a_set = np.linspace(0, 8, 20)에서의 Linear approximation을 사용해서 근사값을 구하시오

# %% [markdown]
# #### (3) Taylor Series를 이용한 2차근사(Quadratic Approximation)
# - Taylor에서 approxiamtion을 위해 2차항까지 이용한 방법
# $$
# \begin{align}
# T_f(x) &\approx \sum_{n=0}^{2} \frac{f^{(n)}(a)}{n!}(x-a)^{n} \\
#        &= f(a) + f^{(1)}(a)(x-a) + \frac{1}{2} f^{(2)}(a)(x-a)^2
# \end{align}
# $$

# %% [markdown]
# ##### (과제 1)<br>
#
# - 함수 $f(x)=(x-4)^2-2$에 대해  a_set = np.linspace(0, 8, 20)에서의 Quadratic approximation을 사용해서 근사값을 구하는 program을 작성하시오

# %% [markdown]
# ### 2.2 Fourier series
#
# - 푸리에 급수(Fourier級數, Fourier series)는 주기 함수를 삼각함수의 가중치로 분해한 급수임 <br>
# $ \ \ $ $\checkmark $ 대부분의 경우, 급수의 계수는 본래 함수와 일대일로 대응함  <br>
# $ \ \ $ $\checkmark $ 함수의 푸리에 계수는 본래 함수보다 다루기 쉽기 때문에 유용하게 사용됨  <br>
#
#
# - 푸리에 급수는 전자 공학, 진동 해석, 음향학, 광학, 신호처리와 화상처리, 데이터 압축 등에 사용되고 있음
#
#
# - 복잡한 함수 $f(x)$를 우리가 잘 다룰 수 있는 $sin  \theta, cos \theta, ..., $로 변환하는 방법

# %% [markdown]
# #### (1) Fourier Series 정의
# > - 푸리에 급수는 주기함수를 기본적인 조화함수인 삼각함수 또는 복소 지수 함수의 급수로 나타낸 것임<br>
# (1) 주기함수 $f: R \rightarrow C$(복소수)가 $T$의 주기를 가지는 함수라고 하자. 즉,
# <br>
# <br>
# $$
# f(x) = f(x+T)
# $$
# <br>
# (2) 또한 $f$가 모든 유한 구간(finite interval)에서 제곱적분 가능하다고 하자. <br> $\quad$ 즉, 임의의 $a, b \in R$에 대하여 $\int_{a}^{b} |f|^2 dx$가 유한한 값으로 존재한다고 하자<br>
# 그렇다면 $f$의 푸리에 계수(Fourier coefficient) $g_n$을 다음과 같이 정의한다<br><br>
# $$
# g_n = \frac{1}{T} \int_{t_0}^{t_0 + T} exp \left( - \frac{2n \pi ix}{T} \right) f(x) dx, t_o \in R
# $$<br>
# 그렇다면 다음이 성립한다. 임의의 $x \in R$에 대하여, 다음식이 성립하지 않는 $x$의 집합은 로베그 측도* 0을 가진다
# <br>
# <br>
# $$
# \begin{align}
# f(x) =& \sum_{n=-\infty}^{\infty} g_n  exp \left( - \frac{2n \pi ix}{T} \right)  \\
# \rightarrow f(x) =& \sum_{n=-\infty}^{\infty} C_n \left( cos(n \omega t) + i sin(n \omega t) \right) \quad ( Euler's \ \ Rule)
# \end{align}
# $$
# <br>
# 만약 $f$가 연속미분가능$\left( C^1 \right)$ 함수라면(즉, $f$의 도함수가 존재하고 연속적인 경우) $f$의 푸리에 급수는 모든 $x$에서 $f(x)$로 수렴한다
#
#
# * 측도론에서 르베그 측도(영어: Lebesgue measure)는 유클리드 공간의 부분 집합에 길이, 넓이 또는 부피를 할당하는 방법

# %% [markdown]
# #### (2) Fourior Series를 이용한 계단함수 Approximation의 예
#
# - 다음과 같은 계단함수를 Fourior Series로 Approximation하보면 다음과 같음
#
# $$
# \begin{align}
# f(x) =&
# \begin{cases}
# 0, &       if \ 0 \le x  \lt 1   \\
# 1, &       if \ 1 \le x  \lt 2    \\
# 2, &       if \ 2 \le x  \lt 3
# \end{cases} \\\\
# f(x) =& 1 - \frac{3 sin \left( \frac{2 \pi x}{3} \right)}{\pi}
#           - \frac{3 sin \left( \frac{4 \pi x}{3} \right)}{2 \pi}
#           - \frac{3 sin \left( \frac{8 \pi x}{3} \right)}{4 \pi}
#           - \frac{3 sin \left( \frac{10 \pi x}{3} \right)}{5 \pi}
#           + \cdots
# \end{align}
# $$

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# #### (3) 영상 Image의 주파수변환
#
# - 모든 Image는 Pixel값의 변화를  Fourior Series로 Approximation하면 주파수로 변환하여 해석할 수 있음

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3. Statistical Model을 이용한 Approximation

# %% [markdown]
# ### 3.1 다양한 궁금증
#
# - 전주의 초등학교 4학년 학생들의 키 $y$는 왜 다를까?<br>
# $ \ \ $ $\checkmark \ $ 학생 A의 키 $y_1$이 학생 B의 키 $y_2$보다 큰 이유는 무엇일까?<br><br>
# - 아이의 키  $y$에 영향을 미칠 것으로 예상할 수 있는 변수
#
# 변수 | 설명
# :--- |:----
#  $$z_1$$ | 유전자
#  $$z_2$$ | 1일 영양섭취량
#  $$z_3$$ | 스트레스지수
#  $$\vdots$$ | $$\vdots$$
#  $$z_{n_0}$$ | 형제 수
#
# $\qquad$ (i) $y$에 영향을 미칠 것으로 예상되는 $z_1$와 $y$  사이에는 어떤 관계가 있을까? 하나의 Feature $z$와 $y$의 관계<br>
# <br>
# $\qquad$ (ii) $y$에 영향을 미칠 것으로 예상되는 두개의 Feature $z_1$과 $z_2$에 대해,  $z_1$과 $z_2$ 사이에는 어떤 관계가 있을까?<br>
# <br>
# $\qquad$ (iii) $y$에 영향을 미칠 것으로 예상되는 여러개의 Feature들 $z_1, z_2, ..., z_{n_0}$와 $y$  사이에는 어떤 관계가 있을까?  여러개의  <br> $\qquad \quad \ \ \ $ $z_i$변수와 $y$의 관계
#
#
# - 통계학에서, 회귀 분석(regression analysis)은 independent variable들 $z = \left(z_1, ..., z_{n_0}  \right)$과 관찰된 연속형 변수 $y$ 사이의 통계적 Model을 구하는 방법

# %% [markdown]
# ### 3.2 다루는 문제의 상황
# #### (1)   $Data$에 기반한 분석
# - Unknown function: $y=f(x_1, x_2, ..., x_{K})$<br>
# $ \ \ $ $\checkmark \ $ 우리가 생각하고 있는 $f(x_1, ..., x_{K})$가 unknown 함수라는 의미는 세상에 존재하는 임의의  System을  <br> $\quad \ \ $ 대변한다는 의미임<br>
#
#
# - 우리가 다루려고 하는 문제의 상황<br>
# $ \ \ $ $\checkmark \ $ $f(x_1, x_2, ..., x_{K})$는 알 수 없지만  다행히 $Sample$  $y_i, i=1, 2, ..., n$은 얻을 수 있는 상황임<br>
# $ \ \ $ $\checkmark \ $ 이러한 $Sample \ y_i, i=1,2,...,n$들을 통해 unknown 세상을 일부 들여다 볼수 있다는 의미임<br>
#
# #### (2) 관측 가능한 세상
#
# - 다음과 같은 참인 관계에 대해 우리는 오직 $y_i$만을 관측할 수 있음
#
# $$
# y=f(x_1, x_2, ..., x_K)
# $$
#
# - 우리가 가지고 있는 사전지식을 이용하여 $y$에 영향을 미칠 것이라고 짐작되는 Feature들 $z_1, z_2, ..., z_{n_0}$을 선정<br>
# $ \ \ $ $\checkmark \ $  이 때 $z_i$들은 관측 가능한 Feature들임<br>
# $ \ \ $ $\checkmark \ $  우리가 가진 지식을 기반으로 선택한 $z_i$들은 Unknown Feature $x_l$들과 일치할 수도 있고 그렇지 않을 수도 있음<br>
# $ \quad $ $\cdots  \ $  $z_1, z_2, ..., z_{n_0 }$들이 잘 선정되었는지는 feature selection, feature extraction등의 방법을 이용하여 확인하는 <br> $\qquad \ \ $ 과정을 거쳐야함<br>
#
#
# - $ \left( z_1, z_2, ..., z_{n_0} \right)$들과 $y$를 동시에 관측한 후, $z = \left( z_1, ..., z_{n_0} \right)$와 $y$ 의 관계를 근사화(approximation)<br>

# %% [markdown]
# ![image-17.png](attachment:image-17.png)

# %% [markdown]
# #### [참고 1]
#
# - 일반적으로 통계학에서 의미하는 Sample<br>
# $ \ \ $ $\checkmark \ $ 𝑆𝑎𝑚𝑝𝑙𝑒이라는 의미는 모집단(population)에서 추출된 값으로 $iid(𝑖𝑑𝑒𝑛𝑡𝑖𝑐𝑎𝑙 \  𝑖𝑛𝑑𝑒𝑝𝑒𝑛𝑑𝑒𝑛𝑡 \ 𝑑𝑖𝑠𝑡𝑟𝑖𝑏𝑢𝑡𝑖𝑜𝑛)$을 의미함<br>
# $\quad$ $\cdots \ $ 예를들면, $Y \sim N(\mu, \sigma^2)$일 때, $Sample \ Y_1, Y_2, ..., Y_n$은 다음 식이 성립한다<br>
# <br>
# $$
# \begin{align}
# & Y_i \sim N(\mu, \sigma^2), y=1,...,n  \\\\
# & P(Y_1 = y_1, Y_2 = y_2, ...Y_n = y_n) = P(Y_1 = y_1)P(Y_2 = y_2)...P(Y_n = y_n) \\
# & \qquad \qquad \qquad \qquad \qquad  \qquad \qquad  \ \   = \prod_{i=1}^{n}P(Y_i = y_i)
# \end{align}
# $$
# <br>
# - Machine Learning에서의 Data들은 Population으로  추출한 Data는 맞지만 $iid$를 의미하지는 않을 수 있음

# %% [markdown]
# ####  [참고 2]
#
# - 인공지능에서 사용하는 2가지 independent의 의미<br>
# $ \ \ $ $\checkmark \ $  선형대수학: linear independt $a . b = 0$ <br>
# $ \ \ $ $\checkmark \ $  통계학: 확률변수 $X_1, X_2$에 한 결합확률 $P(X_1 = x_1, X_2 = x_2)=P(X_1=x_1) \times P(X_2 = x_2)$

# %% [markdown]
# ### 3.3  Featue $z$와 Label $y$의 관계 파악: 공분산과 상관관계

# %% [markdown]
# ####  (1) 공분산(Covariance)
#
# - 공분산(Covariance)은 <span style="color:red">두 확률변수(pairwise) 간</span>의 <span style="color:red">선형관계</span>를 파악하는 방법<br>
# $ \ \ $ $\checkmark \ $ 동시에 여러개의 확률변수간의 관계를 이야기하는 것이 아님<br>
# $ \ \ $ $\checkmark \ $ 확률변수 $X_1$와 $X_2$의 기댓값과 분산을 각각 $\left( \mu_{1}, \sigma_{1}^2 \right)$과   $\left( \mu_{2}, \sigma_{2}^2 \right)$라고 할 때 공분산$(Covariance)$은 다음과 같이 <br> $\quad \ \ $ 정의됨<br><br>
#
# #### [Covariance 정의]
# >$ \begin{align}
# \qquad  Cov(X_1, X_2) & = E(X_1-\mu_1)(X_2-\mu_2)\\
#                       & = E(X_1 X_2 - \mu_2 X_1 - \mu_1 X_2 + \mu_1 \mu_2)\\
#                       & = E(X_1 X_2) - \mu_2 E(X_1) - \mu_1 E(X_2) + \mu_1 \mu_2\\
#                       & = E(X_1 X_2) - \mu_1 \mu_2
# \end{align}$<br><br>

# %% [markdown]
# #### [공분산행렬(Covariance Matrix)]
#
# - Column vector인  확률변수 $X=(X_1, ..., X_m)$와 $Y=(Y_1, ..., Y_n)$의 기댓값이 각각 $\mu_X$와 $\mu_Y$라고 할 때 $m \times n$ 공분산행렬은 다음과 같다<br>
#
# $$
# \begin{align}
# Cov(X, Y) =& E\left((X-\mu_X)(Y-\mu_Y)^T\right) \\
# Cov(X, Y) =& Cov(Y, X)^T
# \end{align}
# $$

# %% [markdown]
# #### [표본공분산(Sample Covariance)]
#
# - 피어슨 상관계수에 사용되는 표본 공분산(Sample Covariance)은 다음과 같다.<br>
#
# $$
# \widehat{Cov}(X, Y) = \frac{\sum_{i=1}^{n}(X_i- \bar X)(Y_i- \bar Y)}{n-1}
# $$

# %% [markdown]
# ####  (2) 상관관계(Correlation Coefficient)
#
# - 상관관계는 2개의 Feature간에 선형관계 정도를 Measure하는 방법임<br>
# $ \ \ $ $\checkmark \ $ 비선형 관계는 파악하지 못함<br>
# $ \ \ $ $\checkmark \ $ 2개 이상의 Feature가 관련성을 가질 때 파악할 수 없음 <br>
#
#
# - 모집단(Population)에 적용되는 Pearson's correlation coefficient, $\rho_{X_1 X_2}$<br>
# <br>
#
# $$
# \begin{align}
# \rho_{X_1 X_2} &= \frac{Cov(X_1, X_2)}{\sigma_{X_1}\sigma_{X_2}}
# \end{align}
# $$<br>
#
# $$ -1\le \rho \le 1$$
# <br>
# - 표본(Sample)에 적용되는 Pearson's correlation coefficient, $r_{X_1 X_2}$<br>
#
#
# $$
# \begin{align}
# r_{X_1 X_2} = \frac{S_{X_1 X_2}}   {S_{X_1 X_1} S_{X_2 X_2}}
# \end{align}
# $$<br>
# <br>
# $ \qquad$ 여기서 $S_{X_1 X_2} = \sum_{i=1}^n (x_{1i}-\bar{x_1})(x_{2i}-\bar{x_2})$,
# $S_{X_1 X_1} = \sqrt{     \sum_{i=1}^n (x_{1i}-\bar{x_1})^2   }$,
# $S_{X_2 X_2} = \sqrt{     \sum_{i=1}^n (x_{2i}-\bar{x_2})^2   }$<br>

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### 3.4  Featue $z$와 Label $y$의 관계 파악: 선형회귀분석
# #### (1) 선형회귀의 Model과 가정
# - 선형회귀(Linear regression)는 종속 변수 $y$와 한 개 이상의 Feature (독립 변수 또는 설명 변수) $z=\left(z_1, \cdots ,z_{n_0}  \right)$와의 선형 관계를 추정하는 통계적 모델링 기법
#
#
# $$
# \begin{align}
# Model에 \ 대한 \ 가정: \ y &= w_0 + w_1 z_1 + \cdots + w_{n_0} z_{n_0} + \varepsilon \quad (선형근사) \\\\
# Error에 \ 대한 \ 가정: \  \varepsilon & \sim (0, \Sigma), \quad Constant \ variance
# \end{align}
# $$ <br>
#
# $$
# \begin{align}
# \Sigma
#  &=
# \begin{bmatrix}
# \sigma_{11} & \cdots &  \sigma_{1c} \\
# \vdots & \ddots & \vdots \\
# \sigma_{c1} & \cdots &  \sigma_{nn}
# \end{bmatrix} \\\\
# \sigma_{ij} &= E \left[ \varepsilon_i - E \left( \varepsilon_i \right) \right] \left[ \varepsilon_i - E \left( \varepsilon_i \right) \right] = E \left(  \varepsilon_i \varepsilon_j \right)
# \end{align}
# $$

# %% [markdown]
# #### (2) 관측 Data와 선형회귀 Model

# %% [markdown]
# ![image-12.png](attachment:image-12.png)

# %% [markdown]
# ## [생각해보기]
#
# - 근사화방법에서 생각해 보아야할 점 중의 하나는  근사화 한 값이 참값과 얼마나 떨어져 있는가?임<br>
# $ \ \ $ $\checkmark \ $ 예를 들어 원주율 $\pi$를 $3.14$로 근사화 했다면, $\pi$가 무한소수이기 때문에 내가 다룰 수 없는데  참값과의 차이를 어떻게 알수 있을까?

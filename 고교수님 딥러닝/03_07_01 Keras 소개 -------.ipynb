# %% [markdown]
# # keras 소개
# - (참고자료) <br>
# \- Deep Learning with python code master by Fransois Chollet<br>
# \- Hands on Machine Learning with Scikit-Learn, Keras and Tensorflow [2 edition] bt Aurelien, Geron

# %% [markdown]
# https://keras.io/ko/

# %% [markdown]
# ## 1. keras 운영환경
# * Python 3.5–3.8
# * Ubuntu 16.04 or later
# * Windows 7 or later
# * macOS 10.12.6 (Sierra) or later.

# %% [markdown]
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# 구분 | 용어 |  $\qquad \qquad $ 설명
# :----: | :----: | :----
# <br> Low-level Library | <br> Eigen | <br> $\bullet$  Eigen은 행렬, 벡터, 수치 solver 및 관련 algorithm과 같은 선형대수학을 위한 C++ 템플릿  <br> $ \ \ $ Library
#  <br> Low-level Library | <br> BLAS | <br> $\bullet$ Basic Linear Algebra Subprograms (BLAS)는 벡터 덧셈, 스칼라 곱셈, 닷프로덕트, 선형  <br> $ \ \ $ 조합, 행렬 곱셈등의 일반적인 선형대수 연산을 수행하는 Low level 루틴 집합을 명세한 <br> $ \ \ $ 규약임 <br>  $\bullet$  BLAS는 선형대수 library들을 위한 low level 루틴의 사실상 표준 <br> $\bullet$ Armadillo, LAPACK, LINPACK, GNU Octave, Mathematica, MATLAB, NumPy, R, Julia를   <br> $ \ \ $  비롯한 많은 수치연산 소프트웨어는 BLAS-호환 library를 사용하여 선형대수 연산을  <br> $ \ \ $  처리함
#  <br> Low-level Library | <br> cuDNN | <br> $\bullet$ cuDNN(CUDA® Deep Neural Network library) <br> $\bullet$ NVIDIA CUDA Deep Neural Network library, 즉 Deep Neural Network를 위한 GPU 가속화   <br> $ \ \ $ library의 기초 요소로 컨볼루션(Convolution), 풀링(Pooling), 표준화(Nomarlization),   <br> $ \ \ $ 활성화(Activation)와 같은 일반적인 루틴을 빠르게 이행할 수 있도록 하는 library
# <br> Low-level Library | <br> CUDA | <br>  $\bullet$ CUDA(Compute Unified Device Architecture)는 그래픽 처리 장치(GPU)에서 수행하는   <br> $ \ \ $ (병렬 처리) Algorithm을 C 프로그래밍 언어를 비롯한 산업 표준 언어를 사용하여 작성할   <br> $ \ \ $ 수 있도록 하는 GPGPU 기술 <br>   $\bullet$ CUDA는 NVIDIA 이외의 그래픽카드에서 작동하지 않음
# <br> Backend Framework | <br> 텐서플로 <br> (Tensorflow) | <br>  $\bullet$ 텐서플로(TensorFlow)는 다양한 작업에 대해 데이터 흐름 프로그래밍을(머신 러닝) 위한   <br> $ \ \ $ 오픈소스 소프트웨어 library임 <br> $\bullet$ 심볼릭 수학 library이자, 인공 신경망같은 기계 학습 응용프로그램에도 사용됨 <br>   $\bullet$ 텐서플로는 연산그래프를 이용함으로써 분산처리가 가능함 <br>  $\bullet$ 자동미분 기능이 있음
# <br> Backend Framework | <br> 티아노 <br> (Theano) | <br> $\bullet$ 티아노는 몬트리올대학에서 개발한 Python과 NumPy의 문법을 이용하여 표현된 Deep   <br> $ \ \ $ Learning Library로 2008년 부터 사용되어옴  <br>   $\bullet$  티아노는 실행될 때 자동으로 C++ 혹은 CUDA코드로 변환된 뒤에 Python모듈로 로딩됨
# <br> Backend Framework | <br> CNTK | <br>   $\bullet$ CNTK(Computational Network Toolkit)는 Microsoft가 공개한  Open Source Deep Learning <br> $ \ \ $ Framework임  <br>   $\bullet$  파이썬/C++/C# 언어의 인터페이스를 제공   <br>   $\bullet$ 여러 서버를 통한 분산컴퓨팅이 가능
#
#
# * keras는 tensor 처리 library로 tensorflow를 사용하도록 default setting 되어 있음

# %% [markdown]
# ## 2. keras의 Data 구조, Architecture 및 Methods

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3. keras Model 구성
# ### 3.1 Layer 설정
# - keras의 주요 데이터 구조는 model로 Layer를 조직하는 방식임
# - 가장 간단한 종류의 모델인 Sequential 모델은 Layer를 선형적으로 쌓는 방법임
# - 보다 복잡한 구조를 만드려면, Keras functional API를 사용하여 레이어로 임의의 Network으로 구축하면 됨

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

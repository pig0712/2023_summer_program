# %% [markdown]
# ## python

# %%
# 아 너무하기 싫다.

# %% [markdown]
# ## pandas

# %%
import pandas as pd

# %% [markdown]
# ## seaborn

# %%
import seaborn as sb

# %% [markdown]
# ## matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %% [markdown]
# ## 영상처리

# %% [markdown]
# ## 구글 드라이브 연동
